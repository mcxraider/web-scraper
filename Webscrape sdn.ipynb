# %%
#Created 2023-01-09 @ 1900 Hrs
#Final Product at 2023-01-12 @ 1020 Hrs
#Updated for scraping single pages on 2023-01-32 @ 2140 Hrs

###packages used###

import requests  #pip install requests
from bs4 import BeautifulSoup #pip install bs4
import re
import pandas as pd #pip install pandas
import openpyxl #pip install openpyxl

import time
import xlwings as xw #pip install xlwings

from selenium import webdriver #pip install selenium
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager #pip install web-driver
from selenium.webdriver.common.by import By

# %%
start_url='https://www.sdn.sg/forindividuals/Pages/Dating-Events-Month.aspx' 
# the url used for reference >> one indicating dating events hosted in the current year
start_sheet=requests.get(start_url)

# %%
driver=webdriver.Chrome()

# %%
def get_data(content): # function specific to the url above; used to extract certain information form the html content of the url
    soup=BeautifulSoup(content, 'html.parser')
    info=soup.find_all(class_="event_cal_height1") # information can be found under this class in the url

    df=pd.DataFrame(columns=['Date','Event','Agency','Cost','Time','Venue','Details']) # creates empty dataframe

    for i in info:
        url=re.findall('<a href="(\S*)">',str(i.contents)) # uses regex to pull out relevant info
        details=('https://www.sdn.sg'+url[0]) # full url for further info on event (useful due to unique event id it possesses)
        extract=[x for x in re.findall('\S*',str(i.text)) if x!='']
        date=(' '.join(extract[:2])) # pulls out the date (in format of mon, day)
        name=(' '.join(extract[2:extract.index('Agency')-1])) # pulls out name of event
        agency=(' '.join(extract[extract.index('Agency')+2:extract.index('Cost')])) # pulls out agency hosting the event
        cost=float(' '.join(extract[extract.index('Cost')+3:extract.index('Time')])) # pulls out the cost of the event (digits only)
        time=(' '.join(extract[extract.index('Time')+2:extract.index('Venue')])) # pulls time of the event (from what time to what time)
        venue=(' '.join(extract[extract.index('Venue')+2:])) # pulls out location of event
        df.loc[len(df)]=[date,name,agency,cost,time,venue,details] # stores all that info in the df

        df=df.iloc[::-1] # reverses order of dataframe (so that recent entries are stored on top)
        df.index=range(0,len(df)) # ensures that index of df is continuous
    return df

# %%
driver.get(start_url)
curr_page_source=driver.page_source
og=pd.DataFrame(columns=['Date','Event','Agency','Cost','Time','Venue','Details'])

soup=BeautifulSoup(driver.page_source, 'html.parser')
time.sleep(5)

# %%
parent=soup.find('div',{'class':'pageLink'}) # search for pagination
children= parent.findChildren('a',recursive=False)

upper=soup.find('div',{'class':'eventmonth'})# search for month


for e in upper.find_all(class_='button'):

    id=(re.findall('id="(.*)" style',str(e)))[0]
    driver.find_element(By.ID,id).click() # finds and clicks each page button on the link (necessary as url is hyperlinked)
    # diff 
    mon=pd.DataFrame(columns=['Date','Event','Agency','Cost','Time','Venue','Details'])
    if get_data(driver.page_source).empty:
        print('Done')
        break 
    else:
        i=0
        while True:
            try:
                driver.find_element(By.LINK_TEXT,(str(i+1))).click() 
                i+=1
            except:
                curr_page_source=driver.page_source
                if (get_data(curr_page_source).empty):
                    break

                else:
                    n=get_data(curr_page_source)
                    mon=pd.concat([mon,n],axis=0)
                    break
            else:
                curr_page_source=driver.page_source
                if (get_data(curr_page_source).empty):
                    break 
                else:
                    n=get_data(curr_page_source)
                    mon=pd.concat([mon,n],axis=0)
        mon=mon.sort_values('Date',ascending=False) 
    og=pd.concat([mon,og],axis=0)
# Out:
# Done

# %%
og=og.drop_duplicates('Details').reset_index(drop=True)

# %%
og.index=(list(range(1,len(og)+1)))
# Out:
#       Date                                              Event  \
# 1   Apr 29         Match by Age Date (Without Photo Exchange)
# 2   Apr 27  Match by Age Date (With Photo Exchange) - 1 lu...
# 3   Apr 22         Speed Dating for Singles 25 - 37 years old
# 4   Apr 22         Speed Dating for Singles 38 - 50 years old
# 5   Apr 15  Dinner for Ladies 41 - 50, Gentlemen 44 - 55 (...
# 6   Apr 15  Dinner for Ladies 30 - 40, Gentlemen 32 - 43 (...
# 7   Apr 14            If You Have What It Takes (Fri, 14 Apr)
# 8   Apr 08                      40 Singles Group Speed Dating
# 9   Apr 07  Panoramic Sunset Drinks at Moon Bar (Fri, 7 Ap...
# 10  Apr 01                      "Age is just a Number" Dating
# 11  Apr 01  Revelatory DinnerDates: age range & income ran...
# 12  Mar 25  Express Personal Profile Dating - 1 date with ...
# 13  Mar 25  Lunch Date for Busy Working Professionals (Sin...
# 14  Mar 25  Match by "Age & Religion" 1-1 Face-to-Face Dat...
# 15  Mar 25               Make Tea, Make Friends (Sat, 25 Mar)
# 16  Mar 24  Graduates Night: 6 local universities (Fri, 24...
# 17  Mar 18      10-minutes Slow Speed Dating (Singles </= 40)
# 18  Mar 18      10-minutes Slow Speed Dating (Singles >/= 40)
# 19  Mar 11  Tea Date for Single Polytechnic Graduates (Sin...
# 20  Mar 11  Tea Date for Singles from Single Gender School...
# 21  Mar 11  DinnerDates: Featuring Age Range & Income Rang...
# 22  Mar 11                 Match by Age 1-1 Face-to-Face Date
# 23  Mar 04   Speed Dating for Ladies </= 34, Gentlemen </= 37
# 24  Mar 04  Speed Dating for Ladies 35 - 45, Gentlemen 38 ...
# 25  Mar 03                     PMEs Get-together (Fri, 3 Mar)
# 26  Mar 01                    Express Personal Profile Dating
# 27  Feb 26  Lunch Date for Single Foreign University Gradu...
# 28  Feb 26  Lunch Date for Single Local University Graduat...
# 29  Feb 25  Speed Dating for Ladies 35 - 45, Gentlemen 38 ...
# 30  Feb 19                 Match by Age 1-1 Face-to-Face Date
# 31  Feb 18  Speed Dating for Ladies 28 - 38, Gentlemen 30 ...
# 32  Feb 17                      Graduates night (Fri, 17 Feb)
# 33  Feb 14  Valentine's Day Dinner @ Instagrammable Cafe (...
# 34  Feb 12  Cosy Group Lunch Date (Buddhists & Free-thinke...
# 35  Feb 12  Cosy Group Lunch Date (Christians & Catholics ...
# 36  Feb 11           Valentine's Day Speed Dating (NEW VENUE)
# 37  Feb 08  Workshop - The Astrology of Attraction: Your U...
# 38  Feb 04            Music & Drinks at Moon Bar (Sat, 4 Feb)
# 39  Jan 29                       Dating over Western High Tea
# 40  Jan 29             Cosy Group Lunch Date (Singles </= 35)
# 41  Jan 29            Cosy Group Lunch Date (Singles 40 - 55)
# 42  Jan 28           HaPpy BirthDay to EveryBody Speed DaTing
# 43  Jan 27                                      Who is the X?
# 44  Jan 19           Scoops of love (Ladies 43>=, Gents 46>=)
# 45  Jan 15                 Match by Age 1-1 Face-to-Face Date
# 46  Jan 15                 Lunch Date for Poly Alumni Singles
# 47  Jan 14  An Exclusive Fine Dine (Ladies 25-34, Gents 28...
# 48  Jan 14  Speed Dating for Ladies 30 - 40, Gentlemen 32 ...
# 49  Jan 11  Workshop - The Astrology of Attraction: Your U...
# 50  Jan 08                     Dating over Peranakan High Tea
# 51  Jan 07       Dine by the Lake (Ladies 34-43, Gents 37-46)
# 52  Jan 07         New Year, New Start, New Hope Speed Dating
# 53  Jan 01                    Express Personal Profile Dating
#
#                     Agency  Cost                  Time  \
# 1               CompleteMe  52.0   12:00 PM to 3:00 PM
# 2               CompleteMe  99.0  11:30 PM to 11:45 PM
# 3               CompleteMe  47.0    2:00 PM to 4:30 PM
# 4               CompleteMe  47.0    2:30 PM to 5:00 PM
# 5               CompleteMe  73.0    6:30 PM to 8:30 PM
# 6               CompleteMe  73.0    7:00 PM to 9:00 PM
# 7             One Plus One  10.0    7:00 PM to 8:45 PM
# 8               CompleteMe  47.0    2:00 PM to 5:30 PM
# 9             One Plus One  10.0    5:45 PM to 7:30 PM
# 10              CompleteMe  47.0    2:30 PM to 5:00 PM
# 11            One Plus One  10.0    6:30 PM to 9:00 PM
# 12              CompleteMe  69.0  11:30 PM to 11:45 PM
# 13              CompleteMe  52.0   12:00 PM to 2:30 PM
# 14              CompleteMe  68.9   12:00 PM to 3:00 PM
# 15            One Plus One  10.0    7:15 PM to 9:15 PM
# 16            One Plus One  10.0    7:00 PM to 8:45 PM
# 17              CompleteMe  47.0    2:00 PM to 4:30 PM
# 18              CompleteMe  47.0    2:30 PM to 5:00 PM
# 19              CompleteMe  47.0    2:30 PM to 5:00 PM
# 20              CompleteMe  47.0    2:30 PM to 5:00 PM
# 21            One Plus One  10.0    6:30 PM to 8:30 PM
# 22              CompleteMe  52.0   12:00 PM to 3:00 PM
# 23              CompleteMe  47.0    2:00 PM to 4:30 PM
# 24              CompleteMe  47.0    2:00 PM to 4:30 PM
# 25            One Plus One  10.0    7:00 PM to 8:45 PM
# 26              CompleteMe  69.0  12:00 AM to 11:45 PM
# 27              CompleteMe  52.0   12:00 PM to 2:00 PM
# 28              CompleteMe  52.0   12:00 PM to 2:00 PM
# 29              CompleteMe  47.0    2:00 PM to 4:30 PM
# 30              CompleteMe  52.0   12:00 PM to 3:00 PM
# 31              CompleteMe  47.0    2:00 PM to 4:30 PM
# 32            One Plus One  10.0    7:00 PM to 8:45 PM
# 33              CompleteMe  68.9    7:00 PM to 9:00 PM
# 34              CompleteMe  52.0   12:00 PM to 2:00 PM
# 35              CompleteMe  52.0   12:00 PM to 2:00 PM
# 36              CompleteMe  47.0    2:00 PM to 4:30 PM
# 37              CompleteMe  47.0    7:00 PM to 9:00 PM
# 38            One Plus One  10.0    5:30 PM to 7:00 PM
# 39              CompleteMe  41.0    2:00 PM to 4:00 PM
# 40              CompleteMe  52.0   12:00 PM to 2:00 PM
# 41              CompleteMe  52.0   12:00 PM to 2:00 PM
# 42              CompleteMe  47.0    2:00 PM to 4:00 PM
# 43  Dating Moments Pte Ltd  50.0    7:15 PM to 9:45 PM
# 44  Dating Moments Pte Ltd  32.0    7:00 PM to 9:00 PM
# 45              CompleteMe  52.0   12:00 PM to 2:00 PM
# 46              CompleteMe  52.0   12:00 PM to 2:00 PM
# 47  Dating Moments Pte Ltd  60.0    6:00 PM to 8:00 PM
# 48              CompleteMe  47.0    2:00 PM to 4:00 PM
# 49              CompleteMe  38.0    7:00 PM to 9:00 PM
# 50              CompleteMe  41.0    2:00 PM to 4:00 PM
# 51  Dating Moments Pte Ltd  56.0    6:00 PM to 8:45 PM
# 52              CompleteMe  47.0    2:00 PM to 4:00 PM
# 53              CompleteMe  69.0  12:00 AM to 11:45 PM
#
#                                                 Venue  \
# 1                                                Town
# 2                                                Town
# 3                                                Town
# 4                                                Town
# 5                                                Town
# 6                                                Town
# 7   restaurant in town. Disclosed only to confirm ...
# 8                                                Town
# 9   Moon Rooftop Bar. 70 Anson Road, #27-01, Hub S...
# 10                                               Town
# 11  restaurant in town. Disclosed only to confirm ...
# 12                                               Town
# 13                                               Town
# 14                                               Town
# 15        Tea Chapter. 9 Neil Road, Singapore 088808.
# 16  restaurant in town. Disclosed only to confirm ...
# 17                                               Town
# 18                                               Town
# 19                                               Town
# 20                                               Town
# 21  restaurant in town. Disclosed only to confirm ...
# 22                                               Town
# 23                                               Town
# 24                                               Town
# 25  restaurant in town. Disclosed only to confirm ...
# 26                                         Restaurant
# 27                                               Town
# 28                                               Town
# 29                                               Town
# 30                                               Town
# 31                                               Town
# 32  restaurant in town. Disclosed only to confirm ...
# 33                                               Town
# 34                                               Town
# 35                                               Town
# 36                                               Town
# 37                                               Town
# 38  Moon Rooftop Bar. 70 Anson Road, #27-01, Hub S...
# 39                                               Town
# 40                                               Town
# 41                                               Town
# 42                                               Town
# 43        3500A Bukit Merah Central, Singapore 159837
# 44  421 Ang Mo Kio Ave 10, #01-1163, Singapore 560421
# 45                                               Town
# 46                                               Town
# 47  Level 20, One Farrer Hotel, 1 Farrer Park Stat...
# 48                                               Town
# 49                                               Town
# 50                                               Town
# 51   97 Hougang Ave 8, Punggol Park, Singapore 538792
# 52                                               Town
# 53                                         Restaurant
#
#                                               Details
# 1   https://www.sdn.sg/forindividuals/Pages/Dating...
# 2   https://www.sdn.sg/forindividuals/Pages/Dating...
# 3   https://www.sdn.sg/forindividuals/Pages/Dating...
# 4   https://www.sdn.sg/forindividuals/Pages/Dating...
# 5   https://www.sdn.sg/forindividuals/Pages/Dating...
# 6   https://www.sdn.sg/forindividuals/Pages/Dating...
# 7   https://www.sdn.sg/forindividuals/Pages/Dating...
# 8   https://www.sdn.sg/forindividuals/Pages/Dating...
# 9   https://www.sdn.sg/forindividuals/Pages/Dating...
# 10  https://www.sdn.sg/forindividuals/Pages/Dating...
# 11  https://www.sdn.sg/forindividuals/Pages/Dating...
# 12  https://www.sdn.sg/forindividuals/Pages/Dating...
# 13  https://www.sdn.sg/forindividuals/Pages/Dating...
# 14  https://www.sdn.sg/forindividuals/Pages/Dating...
# 15  https://www.sdn.sg/forindividuals/Pages/Dating...
# 16  https://www.sdn.sg/forindividuals/Pages/Dating...
# 17  https://www.sdn.sg/forindividuals/Pages/Dating...
# 18  https://www.sdn.sg/forindividuals/Pages/Dating...
# 19  https://www.sdn.sg/forindividuals/Pages/Dating...
# 20  https://www.sdn.sg/forindividuals/Pages/Dating...
# 21  https://www.sdn.sg/forindividuals/Pages/Dating...
# 22  https://www.sdn.sg/forindividuals/Pages/Dating...
# 23  https://www.sdn.sg/forindividuals/Pages/Dating...
# 24  https://www.sdn.sg/forindividuals/Pages/Dating...
# 25  https://www.sdn.sg/forindividuals/Pages/Dating...
# 26  https://www.sdn.sg/forindividuals/Pages/Dating...
# 27  https://www.sdn.sg/forindividuals/Pages/Dating...
# 28  https://www.sdn.sg/forindividuals/Pages/Dating...
# 29  https://www.sdn.sg/forindividuals/Pages/Dating...
# 30  https://www.sdn.sg/forindividuals/Pages/Dating...
# 31  https://www.sdn.sg/forindividuals/Pages/Dating...
# 32  https://www.sdn.sg/forindividuals/Pages/Dating...
# 33  https://www.sdn.sg/forindividuals/Pages/Dating...
# 34  https://www.sdn.sg/forindividuals/Pages/Dating...
# 35  https://www.sdn.sg/forindividuals/Pages/Dating...
# 36  https://www.sdn.sg/forindividuals/Pages/Dating...
# 37  https://www.sdn.sg/forindividuals/Pages/Dating...
# 38  https://www.sdn.sg/forindividuals/Pages/Dating...
# 39  https://www.sdn.sg/forindividuals/Pages/Dating...
# 40  https://www.sdn.sg/forindividuals/Pages/Dating...
# 41  https://www.sdn.sg/forindividuals/Pages/Dating...
# 42  https://www.sdn.sg/forindividuals/Pages/Dating...
# 43  https://www.sdn.sg/forindividuals/Pages/Dating...
# 44  https://www.sdn.sg/forindividuals/Pages/Dating...
# 45  https://www.sdn.sg/forindividuals/Pages/Dating...
# 46  https://www.sdn.sg/forindividuals/Pages/Dating...
# 47  https://www.sdn.sg/forindividuals/Pages/Dating...
# 48  https://www.sdn.sg/forindividuals/Pages/Dating...
# 49  https://www.sdn.sg/forindividuals/Pages/Dating...
# 50  https://www.sdn.sg/forindividuals/Pages/Dating...
# 51  https://www.sdn.sg/forindividuals/Pages/Dating...
# 52  https://www.sdn.sg/forindividuals/Pages/Dating...
# 53  https://www.sdn.sg/forindividuals/Pages/Dating...

# %%
excel_file=r"C:\Users\acer\OneDrive\Desktop\Results.xlsx" # Dependent on location and all; to create excel sheet beforehand on personal computer
xcel=pd.read_excel(excel_file)  
wb=openpyxl.load_workbook(excel_file,data_only=True)
ws=wb['Sheet1']
clr=openpyxl.styles.PatternFill(fill_type=None)

for row in ws["A1":"H2000"]:
    for cell in row:
        cell.fill = clr

wb.save(filename=excel_file)

rows=[]
for i,det in enumerate(og['Details']): # compares new entries based on details (owing to unique event id present in each url)
 if det not in list(xcel['Details']): # thus; even if event is added on a previous date; will still appear
    i+=2
    rows.append(str(i))

# %%
toxl=og
toxl.to_excel(excel_file)
wbx = xw.Book(excel_file)
for e in rows:
    wbx.sheets['Sheet1'].range(f'A{e}:H{e}').color = (255,234,0)
wbx.save(excel_file)
time.sleep(2)
wbx.close()
